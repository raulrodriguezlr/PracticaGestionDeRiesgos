# %% [markdown]
# # 🧪 Notebook de Desarrollo
#
# **Propósito:** Probar código antes de integrarlo en `main.ipynb`
#
# Este notebook es para experimentar libremente. Aquí puedes:
# - Probar fragmentos de código
# - Hacer debugging
# - Explorar datos
# - Romper cosas sin preocuparte
#
# ---

# %%
# Imports básicos
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

print("🧪 Dev notebook listo")

# %% [markdown]
# ## Zona de pruebas

# %%
# Escribe tu código de prueba aquí
pass
